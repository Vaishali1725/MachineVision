# %% [markdown]
# ## Import Libraries

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %% [markdown]
# ## Read Image

# %%
image = plt.imread('index.png')
plt.imshow(image)

# %% [markdown]
# ## Converting into Grayscale

# %%
gray = rgb2gray(image)
# Out:
# <ipython-input-3-553074412d3a>:1: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   gray = rgb2gray(image)

# %% [markdown]
# ## Defining the sobel filters

# %%
sobel_horizontal = np.array([np.array([1, 2, 1]), np.array([0, 0, 0]), np.array([-1, -2, -1])])
print('kernel for detecting horizontal edges')
print(sobel_horizontal)
 
sobel_vertical = np.array([np.array([-1, 0, 1]), np.array([-2, 0, 2]), np.array([-1, 0, 1])])
print('kernel for detecting Vertical edges')
print(sobel_vertical)
# Out:
# kernel for detecting horizontal edges
# [[ 1  2  1]
#  [ 0  0  0]
#  [-1 -2 -1]]
# kernel for detecting Vertical edges
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]

# %% [markdown]
# ## Convoling the filter over image

# %%
out_h = ndimage.convolve(gray, sobel_horizontal, mode='reflect')
out_v = ndimage.convolve(gray, sobel_vertical, mode='reflect')

# %% [markdown]
# ## Plot Result

# %% [markdown]
# ### Horizontal

# %%
plt.imshow(out_h, cmap='gray')

# %% [markdown]
# ### Vertical

# %%
plt.imshow(out_v, cmap='gray')

# %% [markdown]
# ## Laplace Operator

# %% [markdown]
# #### It can define both vertical & horizontal edges at the same time

# %%
kernel_laplace = np.array([np.array([1, 1, 1]), np.array([1, -8, 1]), np.array([1, 1, 1])])
print('Laplacian kernel for detecting vertical & horizontal edges')
print(kernel_laplace)
# Out:
# Laplacian kernel for detecting vertical & horizontal edges
# [[ 1  1  1]
#  [ 1 -8  1]
#  [ 1  1  1]]

# %% [markdown]
# ## Convole filter & Plot result

# %%
out_l = ndimage.convolve(gray, kernel_laplace, mode='reflect')
plt.imshow(out_l, cmap='gray')
