# %% [markdown]
# # Machine Vision : Low Level Operation

# %%
import cv2

# %% [markdown]
# ### Reading & Displaying Image

# %%
image = cv2.imread("/Users/vaishaliyadav/Desktop/lenna.png", cv2.IMREAD_UNCHANGED) # Read The Image
# cv2.imshow("Picture", image) # Frame Title with the image to be displayed 
# cv2.waitKey(5)

# %%
import matplotlib.pyplot as plt 
plt.imshow(image);

# %% [markdown]
# ### Writing Image

# %%
cv2.imwrite("lena1.png", image)
# Out:
# True

# %% [markdown]
# ### Getting Size of Image

# %%
dimensions = image.shape
 
height = image.shape[0]
width = image.shape[1]
channels = image.shape[2]
 
print('Image Dimension    : ',dimensions)
print('Image Height       : ',height)
print('Image Width        : ',width)
print('Number of Channels : ',channels)
# Out:
# Image Dimension    :  (512, 512, 3)
# Image Height       :  512
# Image Width        :  512
# Number of Channels :  3

# %% [markdown]
# ### Resizing Image

# %%
# cv2.imshow("Picture", image)
resize = cv2.resize(image, (256,256))
# cv2.imshow("Picture", image)
# cv2.imshow("Resized Picture", resize) # Resized Image
# cv2.waitKey(0)

# %%
plt.imshow(resize);

# %% [markdown]
# ### Converting Into Gray Scale Image

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # Convert the color image to grayscale image
# cv2.imshow("Gray Picutre", gray) # Display Grayscale image
# cv2.waitKey(0)

# %%
plt.imshow(gray);

# %% [markdown]
# ### Blurring the Image (Gaussian Blur)

# %%
blur = cv2.GaussianBlur(gray, (19,19), 0) 
# cv2.imshow("Blur Picutre", blur) # Display Blur image
# cv2.waitKey(0)

# %%
plt.imshow(blur);

# %% [markdown]
# ### Crop an Image

# %%
face = image[85:250, 85:220]
# cv2.imshow("Face", face)
# cv2.waitKey(0)

# %%
plt.imshow(face);

# %% [markdown]
# ### Patching an Image

# %%
image_copy = image.copy()
imgheight=image.shape[0]
imgwidth=image.shape[1]

# %%
M = 128
N = 128
x1 = 0
y1 = 0
 
for y in range(0, imgheight, M):
    for x in range(0, imgwidth, N):
        if (imgheight - y) < M or (imgwidth - x) < N:
            break
        y1 = y + M
        x1 = x + N
        if x1 >= imgwidth and y1 >= imgheight:
            x1 = imgwidth - 1
            y1 = imgheight - 1
            tiles = image_copy[y:y+M, x:x+N]
            cv2.imwrite('saved_patches/'+'tile'+str(x)+'_'+str(y)+'.jpg', tiles)
            cv2.rectangle(image, (x, y), (x1, y1), (0, 255, 0), 1)
        elif y1 >= imgheight: # when patch height exceeds the image height
            y1 = imgheight - 1
            tiles = image_copy[y:y+M, x:x+N]
            cv2.imwrite('saved_patches/'+'tile'+str(x)+'_'+str(y)+'.jpg', tiles)
            cv2.rectangle(image, (x, y), (x1, y1), (0, 255, 0), 1)
        elif x1 >= imgwidth: # when patch width exceeds the image width
            x1 = imgwidth - 1
            tiles = image_copy[y:y+M, x:x+N]
            cv2.imwrite('saved_patches/'+'tile'+str(x)+'_'+str(y)+'.jpg', tiles)
            cv2.rectangle(image, (x, y), (x1, y1), (0, 255, 0), 1)
        else:
            tiles = image_copy[y:y+M, x:x+N]
            cv2.imwrite('saved_patches/'+'tile'+str(x)+'_'+str(y)+'.jpg', tiles)
            cv2.rectangle(image, (x, y), (x1, y1), (0, 255, 0), 1)

# %%
# cv2.imshow("Patched Image",image)
cv2.imwrite("patched.jpg",image)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# True

# %%
pimage = cv2.imread("patched.jpg")
plt.imshow(pimage)

# %% [markdown]
# ### Edge Detection

# %%
edges = cv2.Canny(image,100,200)
 
# cv2.imshow("Edge Detected Image", edges)
 
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
plt.imshow(edges);

# %% [markdown]
# # Drawing with OpenCV

# %% [markdown]
# ### Drawing Line

# %%
import numpy as np

# %%
img = np.zeros((512,512,3))
img = cv2.line(img,(0,0),(511,511),(255,0,0),10)

# cv2.imshow("Line", img) # Display the line cutting through the image
# cv2.waitKey(0)

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Drawing Rectangle

# %%
img = np.zeros((512,512,3))
img = cv2.rectangle(img,(200,200),(300,300),(0,0,255),10)

# cv2.imshow("Rectangle", img) # Display the rectangle
# cv2.waitKey(0)

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Drawing a Circle

# %%
img = np.zeros((512,512,3))
img = cv2.circle(img,(255,255),100,(0,255,255),10)

# cv2.imshow("Circle", img) # Display the circle
# cv2.waitKey(0)

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Inserting Text

# %%
img = np.zeros((512,512,3))
font = cv2.FONT_HERSHEY_SIMPLEX 
mat = cv2.putText(img, 'Computer Vision', (125,250), 
            font, 1, (0, 0, 255), 3, cv2.LINE_AA) 

# cv2.imshow("TEXT", img) # Display the TEXT
# cv2.waitKey(0)

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Drawing Polygons

# %%
img = np.zeros((512,512,3))

pts = np.array([[25, 70], [25, 160],  
                [110, 200], [200, 160],  
                [200, 70], [110, 20]], 
               np.int32) 

pts=pts.reshape((-1,1,2))
mat = cv2.polylines(img,[pts],True,(0,255,255))

# cv2.imshow("Polygon", img) # Display the Hexagon
# cv2.waitKey(0)

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Accessing Webcam

# %%
# cap = cv2.VideoCapture(0)

# while True:
#     ret, frame = cap.read()
#     cv2.imshow("capture", frame)
    
#     key = cv2.waitKey(1)
    
#     if(key == ord('q')):
#         break
        
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ## Adding & Subtracting Image

# %% [markdown]
# ### Adding

# %%
import numpy as np 
    
image1 = cv2.imread('/Users/vaishaliyadav/Downloads/img1.jpeg') 
image2 = cv2.imread('/Users/vaishaliyadav/Downloads/img2.jpeg')

image = cv2.add(image1, image2)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
plt.imshow(image)

# %% [markdown]
# ### Subtracting

# %%
image = cv2.subtract(image1, image2)
plt.imshow(image)

# %% [markdown]
# ## Open A Video File

# %%
# cap = cv2.VideoCapture('/Users/vaishaliyadav/Downloads/SampleVideo.mp4')
   
# if (cap.isOpened()== False): 
#     print("Error opening video  file")

# while(cap.isOpened()):
#     ret, frame = cap.read()
#     if ret == True:
#         cv2.imshow('Frame', frame)
#         if cv2.waitKey(25) & 0xFF == ord('q'):
#             break
            
#     else: 
#         break

# cap.release()
# cv2.destroyAllWindows()
